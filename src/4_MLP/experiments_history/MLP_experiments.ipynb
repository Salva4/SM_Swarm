# %% [markdown]
# # Run the experiments
# ## Load data and scripts
#
# 1 - Upload zip file (...). \\
# 2 - Run the following commands:

# %%
# !unzip SM_* > null
# !mv SM_*/* . > null
# !rm -r SM_* __MAC* > null

# %%
# %cd src/4_MLP

# %%
# !sh experiments.sh
# Out:
# Training & testing the dataset: lda
# AUC on the test set, partition 1:  0.9006761358389510 	 Running time:  0.0618474483489990
# AUC on the test set, partition 2:  0.8982028552247190 	 Running time:  0.0664238929748535
# AUC on the test set, partition 3:  0.9091496550845215 	 Running time:  0.0577623844146729
# AUC on the test set, partition 4:  0.8986053355511484 	 Running time:  0.0665724277496338
# AUC on the test set, partition 5:  0.8982307121236208 	 Running time:  0.0589706897735596
# AUC on the test set, partition 6:  0.9024660247194632 	 Running time:  0.0574309825897217
# AUC on the test set, partition 7:  0.9031492806457631 	 Running time:  0.0481629371643066
# AUC on the test set, partition 8:  0.8996890184645286 	 Running time:  0.0478191375732422
# AUC on the test set, partition 9:  0.9054163004460363 	 Running time:  0.0447707176208496
# AUC on the test set, partition 10:  0.9029920319570350 	 Running time:  0.0460917949676514
#
# ...

# %% [markdown]
# ## Hyperparameter tuning (reduced example to only lda-balanced)

# %%
# !sh tuning.sh   # Example of hyperparameter tuning (only for lda-balanced,
                #...by modifying the current tuning.sh file).
# Out:
# Tuning hyperparameters for the dataset: lda balanced
# Hyperparameters selection: (AUC: 0.9047650656678203)
# 	Width	8
# 	Depth	2
# 	LR	0.01
# 	Momentum	0.0
